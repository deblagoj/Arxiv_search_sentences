# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import arxiv
import time
import os
from shutil import copyfile


# we don't like warnings
# you can comment the following 2 lines if you'd like to
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('citations.csv',sep = ';', error_bad_lines=False)
df.head()
# Out:
#   MM IHT BD JSG  Comment                                              title  \
# 0                    NaN  A survey on bias and fairness in machine learning
# 1                    NaN                                  Machine behaviour
# 2                    NaN  Fairness and abstraction in sociotechnical sys...
# 3                    NaN  Improving fairness in machine learning systems...
# 4                    NaN  From recognition to cognition: Visual commonse...
#
#                                                 info  \
# 0  N Mehrabi, F Morstatter, N Saxena, K Lermanâ€¦...
# 1  I Rahwan, M Cebrian, N Obradovich, J Bongardâ€...
# 2  AD Selbst, D Boyd, SA Friedlerâ€¦ - Proceeding...
# 3  K Holstein, J Wortman Vaughan, H DaumÃ© IIIâ€¦...
# 4  R Zellers, Y Bisk, A Farhadiâ€¦ - Proceedings ...
#
#                                              snippet  \
# 0  With the widespread use of artificial intellig...
# 1  Abstract Machines powered by artificial intell...
# 2  ABSTRACT A key goal of the fair-ML community i...
# 3  The potential for machine learning (ML) system...
# 4  Visual understanding goes well beyond object r...
#
#                                                 link  \
# 0         https://dl.acm.org/doi/abs/10.1145/3457607
# 1  https://www.nature.com/articles/s41586-019-113...
# 2  https://dl.acm.org/doi/abs/10.1145/3287560.328...
# 3  https://dl.acm.org/doi/abs/10.1145/3290605.330...
# 4  http://openaccess.thecvf.com/content_CVPR_2019...
#
#                                                cites
# 0  ['datasheets for datasets', 'dataset nutrition...
# 1         ['datasheets for datasets', 'model cards']
# 2  ['datasheets for datasets', 'data statements f...
# 3  ['datasheets for datasets', 'data statements f...
# 4                        ['datasheets for datasets']

# %% [markdown]
# ### List of Arxiv

# %%
list=[]
for paper in df['link']:
    if "https://arxiv.org/abs"  in paper:
        index_url = paper.replace('https://arxiv.org/abs/','')
        list.append(index_url)

# %%
len(list)
# Out:
# 252

# %% [markdown]
# ## Download paper from Arxiv

# %%
# Iterrator "i" is set intentionaly to monitor when the connection will break and continue manualy from there
for i in range (len(list)):
    print(i)
    empty_list=[]
    empty_list.append(list[i])
    search = arxiv.Search(id_list=empty_list)
    p = next(search.results())
    print(p.title)
    p.download_pdf(dirpath="arxiv_papers/pdfs")
    time.sleep(5.5)
# Out:
# 0
# Show Your Work: Improved Reporting of Experimental Results
# 1
# The Price of Fair PCA: One Extra Dimension
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/41/qg7dy6wj4d9869gn3lhvspym0000gn/T/ipykernel_15232/5295572.py in <module>
#       7     p = next(search.results())
#       8     print(p.title)
# ----> 9     p.download_pdf(dirpath="arxiv_papers/pdfs")
#      10     time.sleep(5.5)
#
# ~/Code/Arxiv_Datasheet/arxiv-sanity-preserver/env/lib/python3.8/site-packages/arxiv/arxiv.py in download_pdf(self, dirpath, filename)
#     202             filename = self._get_default_filename()
#     203         path = os.path.join(dirpath, filename)
# --> 204         written_path, _ = urlretrieve(self.pdf_url, path)
#     205         return written_path
#     206
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     274
#     275             while True:
# --> 276                 block = fp.read(bs)
#     277                 if not block:
#     278                     break
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in read(self, amt)
#     456             # Amount is given, implement using readinto
#     457             b = bytearray(amt)
# --> 458             n = self.readinto(b)
#     459             return memoryview(b)[:n].tobytes()
#     460         else:
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in readinto(self, b)
#     500         # connection, and the user is reading more bytes than will be provided
#     501         # (for example, reading in 1k chunks)
# --> 502         n = self.fp.readinto(b)
#     503         if not n and b:
#     504             # Ideally, we would raise IncompleteRead if the content-length
#
# ~/opt/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Covert PDFs to TXT

# %%
from io import StringIO
import os

from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser

# %%
files = os.listdir("arxiv_papers")
for i,f in enumerate(files):
    print(f)
    output_string = StringIO()
    try:
        with open('arxiv_papers/'+f, 'rb') as in_file:
            
            parser = PDFParser(in_file)
            doc = PDFDocument(parser)
            rsrcmgr = PDFResourceManager()
            device = TextConverter(rsrcmgr, output_string, laparams=LAParams())
            interpreter = PDFPageInterpreter(rsrcmgr, device)
            for page in PDFPage.create_pages(doc):
                interpreter.process_page(page)
          
            f=f[0:len(f)-3]
        with open('arxiv_papers/txt/'+f+'txt', "w") as text_file:
            text_file.write(output_string.getvalue())
    except:
      print("An exception occurred")
# Out:
# 2105.06370v1.Providing_Assurance_and_Scrutability_on_Shared_Data_and_Machine_Learning_Models_with_Verifiable_Credentials.pdf
# 2105.00687v1.Learning_by_Design_Structuring_and_Documenting_the_Human_Choices_in_Machine_Learning_Development.pdf
# 2106.02636v2.MERLOT_Multimodal_Neural_Script_Knowledge_Models.pdf
# 2005.13421v1.Thirty_Musts_for_Meaning_Banking.pdf
# 2104.01112v2.NaturalProofs_Mathematical_Theorem_Proving_in_Natural_Language.pdf
# 1912.04947v3.Dynamic_Algorithmic_Service_Agreements_Perspective.pdf
# 1911.08354v2.Energy_Usage_Reports_Environmental_awareness_as_part_of_algorithmic_accountability.pdf
# 2010.00330v1.Workflow_Provenance_in_the_Lifecycle_of_Scientific_Machine_Learning.pdf
# 2007.05408v1.Machine_Learning_Explainability_for_External_Stakeholders.pdf
# 1909.06713v1.Human_self_determination_within_algorithmic_sociotechnical_systems.pdf
# 2009.13888v4.Utility_is_in_the_Eye_of_the_User_A_Critique_of_NLP_Leaderboards.pdf
# 2103.06172v2.Fairness_On_The_Ground_Applying_Algorithmic_Fairness_Approaches_to_Production_Systems.pdf
# 2103.00964v1.Practices_for_Engineering_Trustworthy_Machine_Learning_Applications.pdf
# 2103.09710v1.The_Human_Evaluation_Datasheet_1_0_A_Template_for_Recording_Details_of_Human_Evaluation_Experiments_in_NLP.pdf
# 2010.11856v3.XOR_QA_Cross_lingual_Open_Retrieval_Question_Answering.pdf
# 2005.00635v2.Using_Noisy_Self_Reports_to_Predict_Twitter_User_Demographics.pdf
# 2006.06082v3.Towards_Integrating_Fairness_Transparently_in_Industrial_Applications.pdf
# 2104.05928v1.Semantic_maps_and_metrics_for_science_Semantic_maps_and_metrics_for_science_using_deep_transformer_encoders.pdf
# 1811.00103v1.The_Price_of_Fair_PCA_One_Extra_Dimension.pdf
# 2107.12708v1.QA_Dataset_Explosion_A_Taxonomy_of_NLP_Resources_for_Question_Answering_and_Reading_Comprehension.pdf
# 2003.08385v2.X_Stance_A_Multilingual_Multi_Target_Dataset_for_Stance_Detection.pdf
# 2103.10292v1.How_I_failed_machine_learning_in_medical_imaging_shortcomings_and_recommendations.pdf
# 2105.10923v1.Towards_Knowledge_Organization_Ecosystems.pdf
# 2101.02032v4.Socially_Responsible_AI_Algorithms_Issues_Purposes_and_Challenges.pdf
# 1903.12262v1.Towards_Standardization_of_Data_Licenses_The_Montreal_Data_License.pdf
# 2003.08132v1.Gender_Representation_in_Open_Source_Speech_Resources.pdf
# 2106.04008v2.Widening_Access_to_Applied_Machine_Learning_with_TinyML.pdf
# 2002.08512v1.The_Problem_with_Metrics_is_a_Fundamental_Problem_for_AI.pdf
# 2010.05893v2.Large_Scale_Methods_for_Distributionally_Robust_Optimization.pdf
# 2106.08261v2.Physion_Evaluating_Physical_Prediction_from_Vision_in_Humans_and_Machines.pdf
# 2006.16923v2.Large_image_datasets_A_pyrrhic_win_for_computer_vision.pdf
# 2005.00497v3.The_Grammar_of_Interactive_Explanatory_Model_Analysis.pdf
# 1908.10747v1.Language_Tasks_and_Language_Games_On_Methodology_in_Current_Natural_Language_Processing_Research.pdf
# 2104.08465v1.Frequency_based_Distortions_in_Contextualized_Word_Embeddings.pdf
# 2107.09546v1.Responsible_and_Regulatory_Conform_Machine_Learning_for_Medicine_A_Survey_of_Technical_Challenges_and_Solutions.pdf
# 2011.06485v2.Fairness_and_Robustness_in_Invariant_Learning_A_Case_Study_in_Toxicity_Classification.pdf
# 1906.06439v3.Image_Counterfactual_Sensitivity_Analysis_for_Detecting_Unintended_Bias.pdf
# 2106.00858v1.Uncertainty_Characteristics_Curves_A_Systematic_Assessment_of_Prediction_Intervals.pdf
# 2107.13519v1.On_the_state_of_reporting_in_crowdsourcing_experiments_and_a_checklist_to_aid_current_practices.pdf
# 2103.15746v1.Towards_An_Ethics_Audit_Bot.pdf
# 2008.02275v5.Aligning_AI_With_Shared_Human_Values.pdf
# 2105.14372v1.Ten_Quick_Tips_for_Deep_Learning_in_Biology.pdf
# 2101.01860v1.One_shot_Policy_Elicitation_via_Semantic_Reward_Manipulation.pdf
# 2002.10361v2.Multilingual_Twitter_Corpus_and_Baselines_for_Evaluating_Demographic_Bias_in_Hate_Speech_Recognition.pdf
# 1904.07204v1.Tutorial_Safe_and_Reliable_Machine_Learning.pdf
# 2103.14976v2.A_Multistakeholder_Approach_Towards_Evaluating_AI_Transparency_Mechanisms.pdf
# 2007.15207v1.MKQA_A_Linguistically_Diverse_Benchmark_for_Multilingual_Open_Domain_Question_Answering.pdf
# 2105.13782v1.How_to_Split_the_Effect_of_Word_Segmentation_on_Gender_Bias_in_Speech_Translation.pdf
# 2011.13170v1.Anticipatory_Ethics_and_the_Role_of_Uncertainty.pdf
# 2104.11612v1.Understanding_who_uses_Reddit_Profiling_individuals_with_a_self_reported_bipolar_disorder_diagnosis.pdf
# 2102.06366v1.Confounding_Tradeoffs_for_Neural_Network_Quantization.pdf
# 2102.12060v2.Teach_Me_to_Explain_A_Review_of_Datasets_for_Explainable_NLP.pdf
# 2010.12864v2.On_Transferability_of_Bias_Mitigation_Effects_in_Language_Model_Fine_Tuning.pdf
# 2011.02036v1.Un_fairness_in_Post_operative_Complication_Prediction_Models.pdf
# 2012.15738v1.Moral_Stories_Situated_Reasoning_about_Norms_Intents_Actions_and_their_Consequences.pdf
# 2103.03872v1.Rissanen_Data_Analysis_Examining_Dataset_Characteristics_via_Description_Length.pdf
# 2107.06499v1.Deduplicating_Training_Data_Makes_Language_Models_Better.pdf
# 2004.14667v2.NUBIA_NeUral_Based_Interchangeability_Assessor_for_Text_Generation.pdf
# 2012.15349v1.DynaSent_A_Dynamic_Benchmark_for_Sentiment_Analysis.pdf
# 2003.05434v2.Developing_and_Operating_Artificial_Intelligence_Models_in_Trustworthy_Autonomous_Systems.pdf
# 2108.01182v2.Underreporting_of_errors_in_NLG_output_and_what_to_do_about_it.pdf
# 2005.00813v1.Social_Biases_in_NLP_Models_as_Barriers_for_Persons_with_Disabilities.pdf
# 2006.00632v2.Neural_Unsupervised_Domain_Adaptation_in_NLP_A_Survey.pdf
# 2102.03985v1.Multisource_AI_Scorecard_Table_for_System_Evaluation.pdf
# 2106.02833v1.Improving_Automated_Evaluation_of_Open_Domain_Dialog_via_Diverse_Reference_Augmentation.pdf
# 2106.08867v1.Latent_Mappings_Generating_Open_Ended_Expressive_Mappings_Using_Variational_Autoencoders.pdf
# An exception occurred
# 2104.12231v1.Model_based_metrics_Sample_efficient_estimates_of_predictive_model_subpopulation_performance.pdf
# 1910.13913v4.Toward_Gender_Inclusive_Coreference_Resolution.pdf
# 2107.01824v1.Exploring_Data_Pipelines_through_the_Process_Lens_a_Reference_Model_forComputer_Vision.pdf
# 2010.02353v2.Participatory_Research_for_Low_resourced_Machine_Translation_A_Case_Study_in_African_Languages.pdf
# 1912.02675v1.In_AI_We_Trust_Factors_That_Influence_Trustworthiness_of_AI_infused_Decision_Making_Processes.pdf
# 2010.07213v2.Data_Readiness_Report.pdf
# 2101.03970v1.How_Much_Automation_Does_a_Data_Scientist_Want.pdf
# 2107.03844v3.A_Review_of_Bangla_Natural_Language_Processing_Tasks_and_the_Utility_of_Transformer_Models.pdf
# 2003.05251v3.Explainable_Agents_Through_Social_Cues_A_Review.pdf
# 1907.01463v1.Reproducibility_in_Machine_Learning_for_Health.pdf

# %% [markdown]
# ## Analyse TXTs for a string

# %%
KeyStrings =[ 'Who created the dataset', 
             "For what purpose was the dataset created", 
             "Is the dataset self-contained", 
             "When will the dataset be distributed"]

# %%
files = os.listdir("arxiv_papers/txt")
for i,f in enumerate(files):
    try:
        with open("arxiv_papers/txt/"+f, "r") as document:
            read_data = document.read()
            #print(read_data)
            for x in KeyStrings:
                if x in read_data:
                    f=f[0:len(f)-3]
                    copyfile(os.getcwd()+"/arxiv_papers/"+f+"pdf", os.getcwd()+"/arxiv_papers/selected/"+f+"pdf")

    except:
      print("An exception occurred")
# Out:
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
